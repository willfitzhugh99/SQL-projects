# %% [markdown]
# ## Angie Berry TechChak Project
#
# The following is a quick report on the TechChalk project "Angie Berry SQL Task". I wanted to answer the questions posed in this project using SQL queries, so loaded the .csv files into a database using mySQL in DBeaver. Below is an ERD of the data used in this analysis.
#
# <img src="pics/erd.png" width="300"/>
#
# First things first, I set up my environment and altered the date columns to fit mySQL date time format:
#
# <img src="pics/environment.png" width="900"/>
#
# ---
# I then changed the data type for these variabels through the properties tab:
# <img src="pics/date_type.png" width="300"/>
#
# ---
# #### Now the querying can begin.
#
# The first question is "What is Angie’s Berry Corner’s average daily sales volume?".
# <img src="pics/query1.png" width="500"/>
# The answer is Angie's Berry Corner sold an average of 3,408.55 units per day between 6/1/2019 and the end of the day on 8/19/2019.
#
#
# The next quesiton asks about the best selling products at Angie's Berry Corner.
# <img src="pics/query2.png" width="200"/>
# We can see that all products sell relatively equal amounts, but Honeydew is the most popular item.
#
#
# Who are the top 5 loyalty customers for Angie's Berry Corner?
# <img src="pics/query3.png" width="350"/>
# Xenia Veart is the top loyalty customer, and by a long shot. Strangly, she is also listed as an emplyee of the company, which we will see later. Maybe she owns a competing berry business and secretly enjoys a employee discount on Angie's berries. This is suspicious, and I will investigate this later to make sure nothing fishy is going on.
#
# The next question asks "What are the full names of Angie's employees?".
# <img src="pics/query4.png" width="300"/>
# Now that we've established Xenia has been employed by Angie, let's look at some more information on her.
# <img src="pics/query7.png" width="700"/>
# We can see here that Xenia's employment ended right around the time that she made here last purchase, so Angie must have taken care of business. Nothing to worry about.
#
# Now that taht's taken care of, there are a series of questions asking about revenue generated by different products at Angie's Berry Corner, all of which can be asnwered by this query:
# <img src="pics/query5.png" width="300"/>
# As all products were generally sold in equal amounts, the highest priced products generated the most revenue for the company. 'Imbe' generated the most revenue, while 'Kiwi' generated the least, followed closely by 'Banana'.
#
# Who are the longest serving employees with the company?
# <img src="pics/query6.png" width="300"/>
# Delmer Plackstone is the longest serving empoyee, and Federica Trinke is the longest serving active employee.
#
# Next, the project asks for the highest and lowest spending customers. The follwoing query shows the highest spending customers, excluding those without a customer_id and Xenia Veart:
# <img src="pics/query8.png" width="400"/>
# Anallese Deinhardt is the Angie's best customer, who isn't likely stealing from her somehow. To find the lowest spending customers, you could switch the "desc" in the query to "asc", and you would find there are number of loyalty customers who have only purchased one item, which isn't very intersting.
#
# Lasty, the projects asks for the company's busiest hour of day, day of week and month within the recorded period. Answers to these questions are below:
# <img src="pics/query9.png" width="400"/>
# Angie's busiest hour was first thing in the morning at 8am.
# <img src="pics/query10.png" width="450"/>
# Angie's busiest day of the week was Saturday, followed closely by Sunday.
# <img src="pics/query11.png" width="450"/>
# Angie's busiest recorded month was June.
#
# ---
# Thanks for looking through the SQL queries I used to answer the questions posed in TechChalk's SQL task project.
